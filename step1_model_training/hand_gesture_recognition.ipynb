# %%
import os
import cv2
import yaml
import torch
import numpy as np
import pandas as pd
from  torch import nn
import mediapipe as mp
from torch import optim
from datetime import datetime
from torchmetrics import Accuracy
from torch.utils.data import Dataset, DataLoader

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        list_label = label_dict_from_config_file("hand_gesture.yaml")

        self.linear_relu_stack = nn.Sequential(
            ################## Your Code Here ################## Q1
            # '''Hoàn thành đoạn code để xây dựng một model gồm có 4 hidden layer,
            # lần lượt input và output là (63, 128), (128, 128), (128, 128), (128, 128).
            # Layer đầu tiên được theo sau bổi một Relu và Batchnorm1d.
            # Layer thứ 2, 3, và 4 được theo sau bỏi Relu và Dropout với rate lần lượt là 0.4, 0.4, 0.6.
            # Output layer có nhịêm vụ phân loại với input là 128 và output là số lượng class cử chỉ. '''
            nn.Linear(63,128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128,128),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(128,128),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(128,128),
            nn.ReLU(),
            nn.Dropout(0.6),
            nn.Linear(128,len(list_label))
            ####################################################
        )
    def forward(self, x):
        ################## Your Code Here ################## Q2
        ''' Hoàn thành code để thực hiện forward dự đoán cử chỉ với input x.
        Thực hiện flatten x
        Pass x vừa flatten vào linear_relu_stack
        Return  logits (outputs từ layer cuối cùng)
        '''
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits
        ####################################################

    def predict(self,x,threshold=0.8):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        chosen_ind = torch.argmax(softmax_prob,dim=1)
        return torch.where(softmax_prob[0,chosen_ind]>threshold,chosen_ind,-1)

    def predict_with_known_class(self,x):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        return torch.argmax(softmax_prob,dim=1)

    def score(self,logits):
        return -torch.amax(logits,dim=1)

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path,"r") as f:
       label_tag = yaml.full_load(f)["gestures"]
    return label_tag

# %%
class HandLandmarksDetector():
    def __init__(self) -> None:
        self.mp_drawing = mp.solutions.drawing_utils
        self.mp_drawing_styles = mp.solutions.drawing_styles
        self.mp_hands = mp.solutions.hands
        self.detector = self.mp_hands.Hands(False,max_num_hands=1,min_detection_confidence=0.5)

    def detectHand(self,frame):
        hands = []
        frame = cv2.flip(frame, 1)
        annotated_image = frame.copy()
        results = self.detector.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        if results.multi_hand_landmarks is not None:
            for hand_landmarks in results.multi_hand_landmarks:
                hand = []
                self.mp_drawing.draw_landmarks(
                    annotated_image,
                    hand_landmarks,
                    self.mp_hands.HAND_CONNECTIONS,
                    self.mp_drawing_styles.get_default_hand_landmarks_style(),
                    self.mp_drawing_styles.get_default_hand_connections_style())
                for landmark in hand_landmarks.landmark:
                    x,y,z = landmark.x,landmark.y,landmark.z
                    hand.extend([x,y,z])
            hands.append(hand)
        return hands,annotated_image

# %%
class CustomImageDataset(Dataset):
    def __init__(self, data_file):
        self.data = pd.read_csv(data_file)
        self.labels = torch.from_numpy(self.data.iloc[:,0].to_numpy())

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        one_hot_label = self.labels[idx]
        torch_data = torch.from_numpy(self.data.iloc[idx,1:].to_numpy(dtype=np.float32))
        return torch_data, one_hot_label

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.watched_metrics = np.inf

    def early_stop(self, current_value):
        if current_value < self.watched_metrics:
            self.watched_metrics = current_value
            self.counter = 0
        elif current_value > (self.watched_metrics + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
def train(trainloader, val_loader, model, loss_function, early_stopper, optimizer):
    # add auroc score
    best_vloss = 1_000_000
    timestamp = datetime.now().strftime('%d-%m %H:%M')
    for epoch in range(300):
        #training step
        model.train(True)
        running_loss = 0.0
        acc_train = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for batch_number,data in enumerate(trainloader):
            inputs,labels = data

            ################## Your Code Here ################## Q9
            ''' Hoàn thành code để thực hiện reset gradients và dự đoán class cử
            chỉ của inputs
            '''
            optimizer.zero_grad()
            preds = model(inputs)
            ####################################################

            ################## Your Code Here ################## Q10
            ''' Hoàn thành code để thực hiện tính loss dưa vào kết quả dự đoán
            và labels, sau đó thực hiện backwward và update parameters thông qua
            optimizer
            '''
            loss = loss_function(preds, labels)
            loss.backward()
            optimizer.step()

            ####################################################

            acc_train.update(model.predict_with_known_class(inputs), labels)
            running_loss += loss.item()
        avg_loss = running_loss / len(trainloader)
        # validating step
        model.train(False)
        running_vloss = 0.0
        acc_val = Accuracy(num_classes=len(LIST_LABEL), task='MULTICLASS')
        for i, vdata in enumerate(val_loader):
            vinputs, vlabels = vdata
            preds = model(vinputs)
            vloss = loss_function(preds, vlabels)
            running_vloss += vloss.item()
            acc_val.update(model.predict_with_known_class(vinputs), vlabels)

        # Log the running loss averaged per batch
        # for both training and validation
        print(f"Epoch {epoch}: ")
        print(f"Accuracy train:{acc_train.compute().item()}, val:{acc_val.compute().item()}")
        avg_vloss = running_vloss / len(val_loader)
        print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
        print('Training vs. Validation Loss',
                        { 'Training' : avg_loss, 'Validation' : avg_vloss },
                        epoch + 1)
        print('Training vs. Validation accuracy',
                        { 'Training' : acc_train.compute().item()
                        , 'Validation' : acc_val.compute().item() },
                        epoch + 1)

        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            best_model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_best'
            torch.save(model.state_dict(), best_model_path)

        if early_stopper.early_stop(avg_vloss):
            ################## Your Code Here ################## Q5
            ''' Hoàn thành đoạn code bên dưới để  print ra epoch hiện tại và
            minimum watched metric và thoát loop
            '''
            print (f"stopping at epoch {epoch}, minimum: {early_stopper.watched_metrics}")
            break
            ####################################################



    model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_last'
    torch.save(model.state_dict(), model_path)

    print(acc_val.compute())
    return model, best_model_path

# %%
trainset = CustomImageDataset(train_path)
################## Your Code Here ################## Q3
'''Hoàn thành code để thực hiện khởi tạo DataLoader cho trainset với
batch_size 40 và cho phép xáo trộn.'''
train_loader = DataLoader(trainset, batch_size=50, shuffle=True)
####################################################

valset = CustomImageDataset(val_path)
val_loader = DataLoader(valset, batch_size=50, shuffle=False)

################## Your Code Here ################## Q8
'''Hoàn thành code để thực hiện khởi tạo NeuralNetwork model đã xây dựng ở trên,
khởi tạo hàm loss sử dụng CrossEntropyLoss và khởi tạo early stopper với patience
là 30 và min_delta là 0.01
'''
model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience = 30, min_delta = 0.01)
####################################################

################## Your Code Here ################## Q4
'''Hoàn thành code để thực hiện cấu hình Adam optimizer cho các tham số của
model với tốc độ học là 0.0001
'''
optimizer = optim.Adam(model.parameters(), lr=0.0001)
####################################################

model, best_model_path = train(train_loader, val_loader, model, loss_function, early_stopper, optimizer)
# Out:
# Epoch 0:
# Accuracy train:0.23748773336410522, val:0.276450514793396
# LOSS train 1.6008672941298712 valid 1.597583293914795
# Training vs. Validation Loss {'Training': 1.6008672941298712, 'Validation': 1.597583293914795} 1
# Training vs. Validation accuracy {'Training': 0.23748773336410522, 'Validation': 0.276450514793396} 1
# Epoch 1:
# Accuracy train:0.2953876256942749, val:0.34812286496162415
# LOSS train 1.5792588903790428 valid 1.578514854113261
# Training vs. Validation Loss {'Training': 1.5792588903790428, 'Validation': 1.578514854113261} 2
# Training vs. Validation accuracy {'Training': 0.2953876256942749, 'Validation': 0.34812286496162415} 2
# Epoch 2:
# Accuracy train:0.3267909586429596, val:0.3242320716381073
# LOSS train 1.5616309131894792 valid 1.5573774973551433
# Training vs. Validation Loss {'Training': 1.5616309131894792, 'Validation': 1.5573774973551433} 3
# Training vs. Validation accuracy {'Training': 0.3267909586429596, 'Validation': 0.3242320716381073} 3
# Epoch 3:
# Accuracy train:0.37978410720825195, val:0.33788394927978516
# LOSS train 1.5296464250201272 valid 1.5309162934621174
# Training vs. Validation Loss {'Training': 1.5296464250201272, 'Validation': 1.5309162934621174} 4
# Training vs. Validation accuracy {'Training': 0.37978410720825195, 'Validation': 0.33788394927978516} 4
# Epoch 4:
# Accuracy train:0.45142295956611633, val:0.37542662024497986
# LOSS train 1.5004699003128779 valid 1.490774889787038
# Training vs. Validation Loss {'Training': 1.5004699003128779, 'Validation': 1.490774889787038} 5
# Training vs. Validation accuracy {'Training': 0.45142295956611633, 'Validation': 0.37542662024497986} 5
# Epoch 5:
# Accuracy train:0.4690873324871063, val:0.4197952151298523
# LOSS train 1.4472687812078566 valid 1.4412286480267842
# Training vs. Validation Loss {'Training': 1.4472687812078566, 'Validation': 1.4412286480267842} 6
# Training vs. Validation accuracy {'Training': 0.4690873324871063, 'Validation': 0.4197952151298523} 6
# Epoch 6:
# Accuracy train:0.5103042125701904, val:0.44368600845336914
# LOSS train 1.3862366392498924 valid 1.3689309358596802
# Training vs. Validation Loss {'Training': 1.3862366392498924, 'Validation': 1.3689309358596802} 7
# Training vs. Validation accuracy {'Training': 0.5103042125701904, 'Validation': 0.44368600845336914} 7
# Epoch 7:
# Accuracy train:0.5407261848449707, val:0.46416381001472473
# LOSS train 1.2794675259363084 valid 1.2626191476980846
# Training vs. Validation Loss {'Training': 1.2794675259363084, 'Validation': 1.2626191476980846} 8
# Training vs. Validation accuracy {'Training': 0.5407261848449707, 'Validation': 0.46416381001472473} 8
# Epoch 8:
# Accuracy train:0.5642787218093872, val:0.47098976373672485
# LOSS train 1.1506383901550656 valid 1.1394997636477153
# Training vs. Validation Loss {'Training': 1.1506383901550656, 'Validation': 1.1394997636477153} 9
# Training vs. Validation accuracy {'Training': 0.5642787218093872, 'Validation': 0.47098976373672485} 9
# Epoch 9:
# Accuracy train:0.5888125896453857, val:0.511945366859436
# LOSS train 1.017817735671997 valid 1.0039960344632466
# Training vs. Validation Loss {'Training': 1.017817735671997, 'Validation': 1.0039960344632466} 10
# Training vs. Validation accuracy {'Training': 0.5888125896453857, 'Validation': 0.511945366859436} 10
# Epoch 10:
# Accuracy train:0.6084396243095398, val:0.5392491221427917
# LOSS train 0.9144164181890941 valid 0.8977359185616175
# Training vs. Validation Loss {'Training': 0.9144164181890941, 'Validation': 0.8977359185616175} 11
# Training vs. Validation accuracy {'Training': 0.6084396243095398, 'Validation': 0.5392491221427917} 11
# Epoch 11:
# Accuracy train:0.6388616561889648, val:0.5426621437072754
# LOSS train 0.8093624512354533 valid 0.7800199637810389
# Training vs. Validation Loss {'Training': 0.8093624512354533, 'Validation': 0.7800199637810389} 12
# Training vs. Validation accuracy {'Training': 0.6388616561889648, 'Validation': 0.5426621437072754} 12
# Epoch 12:
# Accuracy train:0.6633954644203186, val:0.5563139915466309
# LOSS train 0.7418669348671323 valid 0.7092568551500639
# Training vs. Validation Loss {'Training': 0.7418669348671323, 'Validation': 0.7092568551500639} 13
# Training vs. Validation accuracy {'Training': 0.6633954644203186, 'Validation': 0.5563139915466309} 13
# Epoch 13:
# Accuracy train:0.7144259214401245, val:0.7337883710861206
# LOSS train 0.6873434327897572 valid 0.6354764575759569
# Training vs. Validation Loss {'Training': 0.6873434327897572, 'Validation': 0.6354764575759569} 14
# Training vs. Validation accuracy {'Training': 0.7144259214401245, 'Validation': 0.7337883710861206} 14
# Epoch 14:
# Accuracy train:0.7634935975074768, val:0.7474402785301208
# LOSS train 0.6248641794636136 valid 0.5722096438209215
# Training vs. Validation Loss {'Training': 0.6248641794636136, 'Validation': 0.5722096438209215} 15
# Training vs. Validation accuracy {'Training': 0.7634935975074768, 'Validation': 0.7474402785301208} 15
# Epoch 15:
# Accuracy train:0.810598611831665, val:0.8156996369361877
# LOSS train 0.550925442150661 valid 0.5150774531066418
# Training vs. Validation Loss {'Training': 0.550925442150661, 'Validation': 0.5150774531066418} 16
# Training vs. Validation accuracy {'Training': 0.810598611831665, 'Validation': 0.8156996369361877} 16
# Epoch 16:
# Accuracy train:0.8380765318870544, val:0.9249146580696106
# LOSS train 0.5161965929326557 valid 0.44767014402896166
# Training vs. Validation Loss {'Training': 0.5161965929326557, 'Validation': 0.44767014402896166} 17
# Training vs. Validation accuracy {'Training': 0.8380765318870544, 'Validation': 0.9249146580696106} 17
# Epoch 17:
# Accuracy train:0.8665358424186707, val:0.9692832827568054
# LOSS train 0.4530792690458752 valid 0.3715745367420216
# Training vs. Validation Loss {'Training': 0.4530792690458752, 'Validation': 0.3715745367420216} 18
# Training vs. Validation accuracy {'Training': 0.8665358424186707, 'Validation': 0.9692832827568054} 18
# Epoch 18:
# Accuracy train:0.9077526926994324, val:0.9897611141204834
# LOSS train 0.40695367682547795 valid 0.2881812007787327
# Training vs. Validation Loss {'Training': 0.40695367682547795, 'Validation': 0.2881812007787327} 19
# Training vs. Validation accuracy {'Training': 0.9077526926994324, 'Validation': 0.9897611141204834} 19
# Epoch 19:
# Accuracy train:0.9175662398338318, val:0.9931740760803223
# LOSS train 0.3509169788587661 valid 0.2367698836605996
# Training vs. Validation Loss {'Training': 0.3509169788587661, 'Validation': 0.2367698836605996} 20
# Training vs. Validation accuracy {'Training': 0.9175662398338318, 'Validation': 0.9931740760803223} 20
# Epoch 20:
# Accuracy train:0.9509322643280029, val:0.9931740760803223
# LOSS train 0.2928827433359055 valid 0.18313550568806627
# Training vs. Validation Loss {'Training': 0.2928827433359055, 'Validation': 0.18313550568806627} 21
# Training vs. Validation accuracy {'Training': 0.9509322643280029, 'Validation': 0.9931740760803223} 21
# Epoch 21:
# Accuracy train:0.9538763761520386, val:0.9931740760803223
# LOSS train 0.27281555959156584 valid 0.13203102862462401
# Training vs. Validation Loss {'Training': 0.27281555959156584, 'Validation': 0.13203102862462401} 22
# Training vs. Validation accuracy {'Training': 0.9538763761520386, 'Validation': 0.9931740760803223} 22
# Epoch 22:
# Accuracy train:0.9538763761520386, val:0.9897611141204834
# LOSS train 0.21787707862399874 valid 0.10463918609699856
# Training vs. Validation Loss {'Training': 0.21787707862399874, 'Validation': 0.10463918609699856} 23
# Training vs. Validation accuracy {'Training': 0.9538763761520386, 'Validation': 0.9897611141204834} 23
# Epoch 23:
# Accuracy train:0.9568204283714294, val:0.9931740760803223
# LOSS train 0.19022062598239808 valid 0.06826613090621929
# Training vs. Validation Loss {'Training': 0.19022062598239808, 'Validation': 0.06826613090621929} 24
# Training vs. Validation accuracy {'Training': 0.9568204283714294, 'Validation': 0.9931740760803223} 24
# Epoch 24:
# Accuracy train:0.9754661321640015, val:0.9897611141204834
# LOSS train 0.16341828803221384 valid 0.05536308758504068
# Training vs. Validation Loss {'Training': 0.16341828803221384, 'Validation': 0.05536308758504068} 25
# Training vs. Validation accuracy {'Training': 0.9754661321640015, 'Validation': 0.9897611141204834} 25
# Epoch 25:
# Accuracy train:0.9744848012924194, val:0.9931740760803223
# LOSS train 0.14509249265704835 valid 0.0422632758175799
# Training vs. Validation Loss {'Training': 0.14509249265704835, 'Validation': 0.0422632758175799} 26
# Training vs. Validation accuracy {'Training': 0.9744848012924194, 'Validation': 0.9931740760803223} 26
# Epoch 26:
# Accuracy train:0.9676153063774109, val:0.9931740760803223
# LOSS train 0.12218204282578968 valid 0.041820588250023626
# Training vs. Validation Loss {'Training': 0.12218204282578968, 'Validation': 0.041820588250023626} 27
# Training vs. Validation accuracy {'Training': 0.9676153063774109, 'Validation': 0.9931740760803223} 27
# Epoch 27:
# Accuracy train:0.9764475226402283, val:0.9931740760803223
# LOSS train 0.114725071759451 valid 0.032190394354984164
# Training vs. Validation Loss {'Training': 0.114725071759451, 'Validation': 0.032190394354984164} 28
# Training vs. Validation accuracy {'Training': 0.9764475226402283, 'Validation': 0.9931740760803223} 28
# Epoch 28:
# Accuracy train:0.9793915748596191, val:0.9863481521606445
# LOSS train 0.10162503662563506 valid 0.037741861805746645
# Training vs. Validation Loss {'Training': 0.10162503662563506, 'Validation': 0.037741861805746645} 29
# Training vs. Validation accuracy {'Training': 0.9793915748596191, 'Validation': 0.9863481521606445} 29
# Epoch 29:
# Accuracy train:0.98233562707901, val:0.9931740760803223
# LOSS train 0.08133987842925958 valid 0.02368966144664834
# Training vs. Validation Loss {'Training': 0.08133987842925958, 'Validation': 0.02368966144664834} 30
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9931740760803223} 30
# Epoch 30:
# Accuracy train:0.9852796792984009, val:0.9931740760803223
# LOSS train 0.09464788011142186 valid 0.026672526694407377
# Training vs. Validation Loss {'Training': 0.09464788011142186, 'Validation': 0.026672526694407377} 31
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9931740760803223} 31
# Epoch 31:
# Accuracy train:0.9744848012924194, val:0.9931740760803223
# LOSS train 0.07311943448370412 valid 0.021865919009239104
# Training vs. Validation Loss {'Training': 0.07311943448370412, 'Validation': 0.021865919009239104} 32
# Training vs. Validation accuracy {'Training': 0.9744848012924194, 'Validation': 0.9931740760803223} 32
# Epoch 32:
# Accuracy train:0.98233562707901, val:0.9965870380401611
# LOSS train 0.0828917305029574 valid 0.01597737478490065
# Training vs. Validation Loss {'Training': 0.0828917305029574, 'Validation': 0.01597737478490065} 33
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9965870380401611} 33
# Epoch 33:
# Accuracy train:0.98233562707901, val:0.9931740760803223
# LOSS train 0.06305450458256971 valid 0.021761426270434942
# Training vs. Validation Loss {'Training': 0.06305450458256971, 'Validation': 0.021761426270434942} 34
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9931740760803223} 34
# Epoch 34:
# Accuracy train:0.9852796792984009, val:0.9965870380401611
# LOSS train 0.06285369626822926 valid 0.018618139044216758
# Training vs. Validation Loss {'Training': 0.06285369626822926, 'Validation': 0.018618139044216758} 35
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9965870380401611} 35
# Epoch 35:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.0704913828521967 valid 0.028327186623452388
# Training vs. Validation Loss {'Training': 0.0704913828521967, 'Validation': 0.028327186623452388} 36
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 36
# Epoch 36:
# Accuracy train:0.9901864528656006, val:0.9829351305961609
# LOSS train 0.0678354317233676 valid 0.028421333801816218
# Training vs. Validation Loss {'Training': 0.0678354317233676, 'Validation': 0.028421333801816218} 37
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9829351305961609} 37
# Epoch 37:
# Accuracy train:0.983316957950592, val:0.9931740760803223
# LOSS train 0.059595154509657904 valid 0.017775431610668118
# Training vs. Validation Loss {'Training': 0.059595154509657904, 'Validation': 0.017775431610668118} 38
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9931740760803223} 38
# Epoch 38:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.0625559160308469 valid 0.019842139195740554
# Training vs. Validation Loss {'Training': 0.0625559160308469, 'Validation': 0.019842139195740554} 39
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 39
# Epoch 39:
# Accuracy train:0.9862610697746277, val:0.9965870380401611
# LOSS train 0.05610253899136469 valid 0.014764682271561469
# Training vs. Validation Loss {'Training': 0.05610253899136469, 'Validation': 0.014764682271561469} 40
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9965870380401611} 40
# Epoch 40:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.048687610553488844 valid 0.01910742405622538
# Training vs. Validation Loss {'Training': 0.048687610553488844, 'Validation': 0.01910742405622538} 41
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 41
# Epoch 41:
# Accuracy train:0.98233562707901, val:0.9965870380401611
# LOSS train 0.05332028644070739 valid 0.015675637626069754
# Training vs. Validation Loss {'Training': 0.05332028644070739, 'Validation': 0.015675637626069754} 42
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9965870380401611} 42
# Epoch 42:
# Accuracy train:0.9872424006462097, val:0.9965870380401611
# LOSS train 0.058194103894666546 valid 0.014343135777380667
# Training vs. Validation Loss {'Training': 0.058194103894666546, 'Validation': 0.014343135777380667} 43
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9965870380401611} 43
# Epoch 43:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.040595977123649346 valid 0.012148085424087185
# Training vs. Validation Loss {'Training': 0.040595977123649346, 'Validation': 0.012148085424087185} 44
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 44
# Epoch 44:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.04876829515255633 valid 0.013386045500434799
# Training vs. Validation Loss {'Training': 0.04876829515255633, 'Validation': 0.013386045500434799} 45
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 45
# Epoch 45:
# Accuracy train:0.9892051219940186, val:0.9965870380401611
# LOSS train 0.06022140747379689 valid 0.009842592804488959
# Training vs. Validation Loss {'Training': 0.06022140747379689, 'Validation': 0.009842592804488959} 46
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9965870380401611} 46
# Epoch 46:
# Accuracy train:0.983316957950592, val:0.9965870380401611
# LOSS train 0.050840423797212896 valid 0.012204811297124252
# Training vs. Validation Loss {'Training': 0.050840423797212896, 'Validation': 0.012204811297124252} 47
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9965870380401611} 47
# Epoch 47:
# Accuracy train:0.9892051219940186, val:0.9965870380401611
# LOSS train 0.05352905303949401 valid 0.012021246556893553
# Training vs. Validation Loss {'Training': 0.05352905303949401, 'Validation': 0.012021246556893553} 48
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9965870380401611} 48
# Epoch 48:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.05573546167995248 valid 0.013412442828666826
# Training vs. Validation Loss {'Training': 0.05573546167995248, 'Validation': 0.013412442828666826} 49
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 49
# Epoch 49:
# Accuracy train:0.9862610697746277, val:0.9965870380401611
# LOSS train 0.04106746988725804 valid 0.009345723886478178
# Training vs. Validation Loss {'Training': 0.04106746988725804, 'Validation': 0.009345723886478178} 50
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9965870380401611} 50
# Epoch 50:
# Accuracy train:0.9862610697746277, val:0.9965870380401611
# LOSS train 0.0391633567355928 valid 0.00561528578615859
# Training vs. Validation Loss {'Training': 0.0391633567355928, 'Validation': 0.00561528578615859} 51
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9965870380401611} 51
# Epoch 51:
# Accuracy train:0.9892051219940186, val:0.9965870380401611
# LOSS train 0.04135510230082132 valid 0.005421359013325855
# Training vs. Validation Loss {'Training': 0.04135510230082132, 'Validation': 0.005421359013325855} 52
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9965870380401611} 52
# Epoch 52:
# Accuracy train:0.9882237315177917, val:0.9965870380401611
# LOSS train 0.039585344604260865 valid 0.0069277131494042505
# Training vs. Validation Loss {'Training': 0.039585344604260865, 'Validation': 0.0069277131494042505} 53
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9965870380401611} 53
# Epoch 53:
# Accuracy train:0.9882237315177917, val:0.9965870380401611
# LOSS train 0.042996201442465895 valid 0.010063933384420428
# Training vs. Validation Loss {'Training': 0.042996201442465895, 'Validation': 0.010063933384420428} 54
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9965870380401611} 54
# Epoch 54:
# Accuracy train:0.9872424006462097, val:0.9965870380401611
# LOSS train 0.039206887706227246 valid 0.01211730368913777
# Training vs. Validation Loss {'Training': 0.039206887706227246, 'Validation': 0.01211730368913777} 55
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9965870380401611} 55
# Epoch 55:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.033415128621051 valid 0.009455683961126246
# Training vs. Validation Loss {'Training': 0.033415128621051, 'Validation': 0.009455683961126246} 56
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 56
# Epoch 56:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.04610123323454034 valid 0.007214177300890394
# Training vs. Validation Loss {'Training': 0.04610123323454034, 'Validation': 0.007214177300890394} 57
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 57
# Epoch 57:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.03983633951949222 valid 0.00536607604180972
# Training vs. Validation Loss {'Training': 0.03983633951949222, 'Validation': 0.00536607604180972} 58
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 58
# Epoch 58:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.04885977120803935 valid 0.02101606729532553
# Training vs. Validation Loss {'Training': 0.04885977120803935, 'Validation': 0.02101606729532553} 59
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 59
# Epoch 59:
# Accuracy train:0.9892051219940186, val:0.9965870380401611
# LOSS train 0.05592676649047505 valid 0.013761061761670135
# Training vs. Validation Loss {'Training': 0.05592676649047505, 'Validation': 0.013761061761670135} 60
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9965870380401611} 60
# Epoch 60:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.036174609348000514 valid 0.014177013620610524
# Training vs. Validation Loss {'Training': 0.036174609348000514, 'Validation': 0.014177013620610524} 61
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 61
# Epoch 61:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.03353716557224592 valid 0.017207068569253654
# Training vs. Validation Loss {'Training': 0.03353716557224592, 'Validation': 0.017207068569253654} 62
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 62
# Epoch 62:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.03575102980470374 valid 0.008566232313796718
# Training vs. Validation Loss {'Training': 0.03575102980470374, 'Validation': 0.008566232313796718} 63
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 63
# Epoch 63:
# Accuracy train:0.9892051219940186, val:0.9965870380401611
# LOSS train 0.032020912350465856 valid 0.0065704538729581445
# Training vs. Validation Loss {'Training': 0.032020912350465856, 'Validation': 0.0065704538729581445} 64
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9965870380401611} 64
# Epoch 64:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.02685460512570682 valid 0.01072449876801329
# Training vs. Validation Loss {'Training': 0.02685460512570682, 'Validation': 0.01072449876801329} 65
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 65
# Epoch 65:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.029863648094414247 valid 0.0053830411902708875
# Training vs. Validation Loss {'Training': 0.029863648094414247, 'Validation': 0.0053830411902708875} 66
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 66
# Epoch 66:
# Accuracy train:0.9941118955612183, val:1.0
# LOSS train 0.027439803561373127 valid 0.004024725950292425
# Training vs. Validation Loss {'Training': 0.027439803561373127, 'Validation': 0.004024725950292425} 67
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 1.0} 67
# Epoch 67:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.024379949351506575 valid 0.005257421239396838
# Training vs. Validation Loss {'Training': 0.024379949351506575, 'Validation': 0.005257421239396838} 68
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 68
# Epoch 68:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.04094662370958498 valid 0.00934034407487161
# Training vs. Validation Loss {'Training': 0.04094662370958498, 'Validation': 0.00934034407487161} 69
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 69
# Epoch 69:
# Accuracy train:0.9931305050849915, val:1.0
# LOSS train 0.037129806665082775 valid 0.00450730400480855
# Training vs. Validation Loss {'Training': 0.037129806665082775, 'Validation': 0.00450730400480855} 70
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 1.0} 70
# Epoch 70:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.02821586421868276 valid 0.006401898975961255
# Training vs. Validation Loss {'Training': 0.02821586421868276, 'Validation': 0.006401898975961255} 71
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 71
# Epoch 71:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.03237925050780177 valid 0.011826151387140271
# Training vs. Validation Loss {'Training': 0.03237925050780177, 'Validation': 0.011826151387140271} 72
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 72
# Epoch 72:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.02153338786835472 valid 0.004231285060200207
# Training vs. Validation Loss {'Training': 0.02153338786835472, 'Validation': 0.004231285060200207} 73
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 73
# Epoch 73:
# Accuracy train:0.9941118955612183, val:1.0
# LOSS train 0.037827375422542296 valid 0.003266583380271489
# Training vs. Validation Loss {'Training': 0.037827375422542296, 'Validation': 0.003266583380271489} 74
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 1.0} 74
# Epoch 74:
# Accuracy train:0.9862610697746277, val:0.9965870380401611
# LOSS train 0.05206554788830025 valid 0.005762487307113891
# Training vs. Validation Loss {'Training': 0.05206554788830025, 'Validation': 0.005762487307113891} 75
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9965870380401611} 75
# Epoch 75:
# Accuracy train:0.9901864528656006, val:0.9965870380401611
# LOSS train 0.028983465140862835 valid 0.008328118819766436
# Training vs. Validation Loss {'Training': 0.028983465140862835, 'Validation': 0.008328118819766436} 76
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9965870380401611} 76
# Epoch 76:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.027790391108109838 valid 0.008833656746939292
# Training vs. Validation Loss {'Training': 0.027790391108109838, 'Validation': 0.008833656746939292} 77
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 77
# Epoch 77:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.03719624480055202 valid 0.004100640991699341
# Training vs. Validation Loss {'Training': 0.03719624480055202, 'Validation': 0.004100640991699341} 78
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 78
# Epoch 78:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.027242740372284538 valid 0.007973833730678356
# Training vs. Validation Loss {'Training': 0.027242740372284538, 'Validation': 0.007973833730678356} 79
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 79
# Epoch 79:
# Accuracy train:0.9931305050849915, val:1.0
# LOSS train 0.022997088530766114 valid 0.003538231366292166
# Training vs. Validation Loss {'Training': 0.022997088530766114, 'Validation': 0.003538231366292166} 80
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 1.0} 80
# Epoch 80:
# Accuracy train:0.9931305050849915, val:1.0
# LOSS train 0.02695186292597403 valid 0.004695525027822593
# Training vs. Validation Loss {'Training': 0.02695186292597403, 'Validation': 0.004695525027822593} 81
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 1.0} 81
# Epoch 81:
# Accuracy train:0.9950932264328003, val:1.0
# LOSS train 0.019805497645090025 valid 0.003528794658090343
# Training vs. Validation Loss {'Training': 0.019805497645090025, 'Validation': 0.003528794658090343} 82
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 1.0} 82
# Epoch 82:
# Accuracy train:0.9901864528656006, val:1.0
# LOSS train 0.03703619157230215 valid 0.0038988742427932266
# Training vs. Validation Loss {'Training': 0.03703619157230215, 'Validation': 0.0038988742427932266} 83
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 1.0} 83
# Epoch 83:
# Accuracy train:0.9921491742134094, val:1.0
# LOSS train 0.037231955804773384 valid 0.005650870667068375
# Training vs. Validation Loss {'Training': 0.037231955804773384, 'Validation': 0.005650870667068375} 84
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 1.0} 84
# Epoch 84:
# Accuracy train:0.9931305050849915, val:1.0
# LOSS train 0.026677947990330204 valid 0.003055446891570076
# Training vs. Validation Loss {'Training': 0.026677947990330204, 'Validation': 0.003055446891570076} 85
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 1.0} 85
# Epoch 85:
# Accuracy train:0.9931305050849915, val:1.0
# LOSS train 0.029106544330716133 valid 0.002414634207847636
# Training vs. Validation Loss {'Training': 0.029106544330716133, 'Validation': 0.002414634207847636} 86
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 1.0} 86
# Epoch 86:
# Accuracy train:0.9941118955612183, val:1.0
# LOSS train 0.0201117139520301 valid 0.0030354707755956647
# Training vs. Validation Loss {'Training': 0.0201117139520301, 'Validation': 0.0030354707755956647} 87
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 1.0} 87
# Epoch 87:
# Accuracy train:0.9941118955612183, val:1.0
# LOSS train 0.025389752550316707 valid 0.004009930532371679
# Training vs. Validation Loss {'Training': 0.025389752550316707, 'Validation': 0.004009930532371679} 88
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 1.0} 88
# Epoch 88:
# Accuracy train:0.9931305050849915, val:1.0
# LOSS train 0.02360010117159358 valid 0.0031237287105909672
# Training vs. Validation Loss {'Training': 0.02360010117159358, 'Validation': 0.0031237287105909672} 89
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 1.0} 89
# Epoch 89:
# Accuracy train:0.9921491742134094, val:1.0
# LOSS train 0.028816467550184046 valid 0.004757946184781758
# Training vs. Validation Loss {'Training': 0.028816467550184046, 'Validation': 0.004757946184781758} 90
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 1.0} 90
# Epoch 90:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.019752411415711754 valid 0.010177997771156319
# Training vs. Validation Loss {'Training': 0.019752411415711754, 'Validation': 0.010177997771156319} 91
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 91
# Epoch 91:
# Accuracy train:0.9950932264328003, val:1.0
# LOSS train 0.03214680106334743 valid 0.0053148034968823294
# Training vs. Validation Loss {'Training': 0.03214680106334743, 'Validation': 0.0053148034968823294} 92
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 1.0} 92
# Epoch 92:
# Accuracy train:0.9941118955612183, val:1.0
# LOSS train 0.023736541680548163 valid 0.0022802144344116946
# Training vs. Validation Loss {'Training': 0.023736541680548163, 'Validation': 0.0022802144344116946} 93
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 1.0} 93
# Epoch 93:
# Accuracy train:0.9960745573043823, val:1.0
# LOSS train 0.030245679264355983 valid 0.0022798649827677764
# Training vs. Validation Loss {'Training': 0.030245679264355983, 'Validation': 0.0022798649827677764} 94
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 1.0} 94
# Epoch 94:
# Accuracy train:0.9911677837371826, val:1.0
# LOSS train 0.022369441942178776 valid 0.00408641903914031
# Training vs. Validation Loss {'Training': 0.022369441942178776, 'Validation': 0.00408641903914031} 95
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 1.0} 95
# Epoch 95:
# Accuracy train:0.9950932264328003, val:1.0
# LOSS train 0.02043964633984225 valid 0.003323172936992099
# Training vs. Validation Loss {'Training': 0.02043964633984225, 'Validation': 0.003323172936992099} 96
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 1.0} 96
# Epoch 96:
# Accuracy train:0.9950932264328003, val:1.0
# LOSS train 0.028406303908143724 valid 0.003362732436793673
# Training vs. Validation Loss {'Training': 0.028406303908143724, 'Validation': 0.003362732436793673} 97
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 1.0} 97
# Epoch 97:
# Accuracy train:0.9970559477806091, val:0.9965870380401611
# LOSS train 0.03271891890714566 valid 0.006482887962202237
# Training vs. Validation Loss {'Training': 0.03271891890714566, 'Validation': 0.006482887962202237} 98
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9965870380401611} 98
# Epoch 98:
# Accuracy train:0.9931305050849915, val:1.0
# LOSS train 0.026519271279019967 valid 0.005913586413025011
# Training vs. Validation Loss {'Training': 0.026519271279019967, 'Validation': 0.005913586413025011} 99
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 1.0} 99
# Epoch 99:
# Accuracy train:0.9941118955612183, val:1.0
# LOSS train 0.02324490991997577 valid 0.002824870772627719
# Training vs. Validation Loss {'Training': 0.02324490991997577, 'Validation': 0.002824870772627719} 100
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 1.0} 100
# Epoch 100:
# Accuracy train:0.9941118955612183, val:1.0
# LOSS train 0.026534863869615254 valid 0.0027566262305072087
# Training vs. Validation Loss {'Training': 0.026534863869615254, 'Validation': 0.0027566262305072087} 101
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 1.0} 101
# Epoch 101:
# Accuracy train:0.9911677837371826, val:1.0
# LOSS train 0.06462963783581342 valid 0.0027454696176315943
# Training vs. Validation Loss {'Training': 0.06462963783581342, 'Validation': 0.0027454696176315943} 102
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 1.0} 102
# Epoch 102:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.019668063015810082 valid 0.005150591890166349
# Training vs. Validation Loss {'Training': 0.019668063015810082, 'Validation': 0.005150591890166349} 103
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 103
# Epoch 103:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.026501909652281375 valid 0.008372875518489309
# Training vs. Validation Loss {'Training': 0.026501909652281375, 'Validation': 0.008372875518489309} 104
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 104
# Epoch 104:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.020512099189329006 valid 0.007795823233379906
# Training vs. Validation Loss {'Training': 0.020512099189329006, 'Validation': 0.007795823233379906} 105
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 105
# Epoch 105:
# Accuracy train:0.9960745573043823, val:0.9965870380401611
# LOSS train 0.01226926225215374 valid 0.0054244850958487705
# Training vs. Validation Loss {'Training': 0.01226926225215374, 'Validation': 0.0054244850958487705} 106
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9965870380401611} 106
# Epoch 106:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.014805736862832592 valid 0.0037050036764488445
# Training vs. Validation Loss {'Training': 0.014805736862832592, 'Validation': 0.0037050036764488445} 107
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 107
# Epoch 107:
# Accuracy train:0.9960745573043823, val:0.9965870380401611
# LOSS train 0.02420716328058569 valid 0.006445908209002482
# Training vs. Validation Loss {'Training': 0.02420716328058569, 'Validation': 0.006445908209002482} 108
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9965870380401611} 108
# Epoch 108:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.027561459579460677 valid 0.006273773869149106
# Training vs. Validation Loss {'Training': 0.027561459579460677, 'Validation': 0.006273773869149106} 109
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 109
# Epoch 109:
# Accuracy train:0.9921491742134094, val:0.9965870380401611
# LOSS train 0.03135679493148234 valid 0.005874807473408812
# Training vs. Validation Loss {'Training': 0.03135679493148234, 'Validation': 0.005874807473408812} 110
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9965870380401611} 110
# Epoch 110:
# Accuracy train:0.9911677837371826, val:0.9965870380401611
# LOSS train 0.019112363956602558 valid 0.011119794025034935
# Training vs. Validation Loss {'Training': 0.019112363956602558, 'Validation': 0.011119794025034935} 111
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9965870380401611} 111
# Epoch 111:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.022476354824556483 valid 0.011279401131019995
# Training vs. Validation Loss {'Training': 0.022476354824556483, 'Validation': 0.011279401131019995} 112
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 112
# Epoch 112:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.020183898705346065 valid 0.011553677447428376
# Training vs. Validation Loss {'Training': 0.020183898705346065, 'Validation': 0.011553677447428376} 113
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 113
# Epoch 113:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.017974676944071517 valid 0.013567883935631167
# Training vs. Validation Loss {'Training': 0.017974676944071517, 'Validation': 0.013567883935631167} 114
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 114
# Epoch 114:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.022072110258574997 valid 0.010190092370000533
# Training vs. Validation Loss {'Training': 0.022072110258574997, 'Validation': 0.010190092370000533} 115
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 115
# Epoch 115:
# Accuracy train:0.9970559477806091, val:0.9965870380401611
# LOSS train 0.01646336231247655 valid 0.012816238709821922
# Training vs. Validation Loss {'Training': 0.01646336231247655, 'Validation': 0.012816238709821922} 116
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9965870380401611} 116
# Epoch 116:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.020045714685693383 valid 0.007479389478286673
# Training vs. Validation Loss {'Training': 0.020045714685693383, 'Validation': 0.007479389478286673} 117
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 117
# Epoch 117:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.018388775892422667 valid 0.009675221995507854
# Training vs. Validation Loss {'Training': 0.018388775892422667, 'Validation': 0.009675221995507854} 118
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 118
# Epoch 118:
# Accuracy train:0.9970559477806091, val:0.9965870380401611
# LOSS train 0.014348741299251006 valid 0.010868829817998934
# Training vs. Validation Loss {'Training': 0.014348741299251006, 'Validation': 0.010868829817998934} 119
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9965870380401611} 119
# Epoch 119:
# Accuracy train:0.9980372786521912, val:0.9931740760803223
# LOSS train 0.015994049087610273 valid 0.018857986124316994
# Training vs. Validation Loss {'Training': 0.015994049087610273, 'Validation': 0.018857986124316994} 120
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9931740760803223} 120
# Epoch 120:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.020632083755030874 valid 0.013082282340481774
# Training vs. Validation Loss {'Training': 0.020632083755030874, 'Validation': 0.013082282340481774} 121
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 121
# Epoch 121:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.01473737422687312 valid 0.011814839538715205
# Training vs. Validation Loss {'Training': 0.01473737422687312, 'Validation': 0.011814839538715205} 122
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 122
# Epoch 122:
# Accuracy train:0.9980372786521912, val:0.9965870380401611
# LOSS train 0.009877270531086694 valid 0.009655367370006237
# Training vs. Validation Loss {'Training': 0.009877270531086694, 'Validation': 0.009655367370006237} 123
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9965870380401611} 123
# Epoch 123:
# Accuracy train:0.9980372786521912, val:0.9965870380401611
# LOSS train 0.012946666830906733 valid 0.015397041676105042
# Training vs. Validation Loss {'Training': 0.012946666830906733, 'Validation': 0.015397041676105042} 124
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9965870380401611} 124
# Epoch 124:
# Accuracy train:0.9980372786521912, val:0.9965870380401611
# LOSS train 0.015223676133679137 valid 0.016237912750871903
# Training vs. Validation Loss {'Training': 0.015223676133679137, 'Validation': 0.016237912750871903} 125
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9965870380401611} 125
# Epoch 125:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.020220073017602164 valid 0.02447652259546847
# Training vs. Validation Loss {'Training': 0.020220073017602164, 'Validation': 0.02447652259546847} 126
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 126
# Epoch 126:
# Accuracy train:0.9980372786521912, val:0.9965870380401611
# LOSS train 0.015384111320599914 valid 0.013717169166885887
# Training vs. Validation Loss {'Training': 0.015384111320599914, 'Validation': 0.013717169166885887} 127
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9965870380401611} 127
# Epoch 127:
# Accuracy train:0.9980372786521912, val:0.9965870380401611
# LOSS train 0.03224017671752898 valid 0.023003252585406624
# Training vs. Validation Loss {'Training': 0.03224017671752898, 'Validation': 0.023003252585406624} 128
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9965870380401611} 128
# Epoch 128:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.022235228192238582 valid 0.014951364044179627
# Training vs. Validation Loss {'Training': 0.022235228192238582, 'Validation': 0.014951364044179627} 129
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 129
# Epoch 129:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.02281226107983717 valid 0.01366562973909898
# Training vs. Validation Loss {'Training': 0.02281226107983717, 'Validation': 0.01366562973909898} 130
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 130
# Epoch 130:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.025118931568050312 valid 0.014299925589549881
# Training vs. Validation Loss {'Training': 0.025118931568050312, 'Validation': 0.014299925589549881} 131
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9965870380401611} 131
# Epoch 131:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.00907459874343615 valid 0.013450861362144906
# Training vs. Validation Loss {'Training': 0.00907459874343615, 'Validation': 0.013450861362144906} 132
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 132
# Epoch 132:
# Accuracy train:0.9980372786521912, val:0.9965870380401611
# LOSS train 0.012766519239881919 valid 0.010297131012038108
# Training vs. Validation Loss {'Training': 0.012766519239881919, 'Validation': 0.010297131012038108} 133
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9965870380401611} 133
# Epoch 133:
# Accuracy train:0.9970559477806091, val:0.9897611141204834
# LOSS train 0.02414268551815656 valid 0.012941819256999073
# Training vs. Validation Loss {'Training': 0.02414268551815656, 'Validation': 0.012941819256999073} 134
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9897611141204834} 134
# Epoch 134:
# Accuracy train:0.9931305050849915, val:0.9965870380401611
# LOSS train 0.021966033800882065 valid 0.017247774168528924
# Training vs. Validation Loss {'Training': 0.021966033800882065, 'Validation': 0.017247774168528924} 135
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9965870380401611} 135
# Epoch 135:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.013712700611601273 valid 0.015382435091671217
# Training vs. Validation Loss {'Training': 0.013712700611601273, 'Validation': 0.015382435091671217} 136
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 136
# Epoch 136:
# Accuracy train:0.9970559477806091, val:0.9965870380401611
# LOSS train 0.018667642603672686 valid 0.016481472194797675
# Training vs. Validation Loss {'Training': 0.018667642603672686, 'Validation': 0.016481472194797675} 137
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9965870380401611} 137
# Epoch 137:
# Accuracy train:0.9970559477806091, val:0.9965870380401611
# LOSS train 0.012321600148598441 valid 0.012952422493214044
# Training vs. Validation Loss {'Training': 0.012321600148598441, 'Validation': 0.012952422493214044} 138
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9965870380401611} 138
# Epoch 138:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.014973243155206243 valid 0.013887568214821991
# Training vs. Validation Loss {'Training': 0.014973243155206243, 'Validation': 0.013887568214821991} 139
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 139
# Epoch 139:
# Accuracy train:0.9980372786521912, val:0.9931740760803223
# LOSS train 0.0088909729744219 valid 0.02251533594456608
# Training vs. Validation Loss {'Training': 0.0088909729744219, 'Validation': 0.02251533594456608} 140
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9931740760803223} 140
# Epoch 140:
# Accuracy train:0.9980372786521912, val:0.9965870380401611
# LOSS train 0.016949967259452456 valid 0.017215247474553053
# Training vs. Validation Loss {'Training': 0.016949967259452456, 'Validation': 0.017215247474553053} 141
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9965870380401611} 141
# Epoch 141:
# Accuracy train:0.9980372786521912, val:0.9931740760803223
# LOSS train 0.009524527393902341 valid 0.02300334842900516
# Training vs. Validation Loss {'Training': 0.009524527393902341, 'Validation': 0.02300334842900516} 142
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9931740760803223} 142
# Epoch 142:
# Accuracy train:0.9970559477806091, val:0.9931740760803223
# LOSS train 0.012121243646279686 valid 0.02008593916989317
# Training vs. Validation Loss {'Training': 0.012121243646279686, 'Validation': 0.02008593916989317} 143
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9931740760803223} 143
# Epoch 143:
# Accuracy train:0.9980372786521912, val:0.9931740760803223
# LOSS train 0.013774644688791818 valid 0.018048046451388206
# Training vs. Validation Loss {'Training': 0.013774644688791818, 'Validation': 0.018048046451388206} 144
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9931740760803223} 144
# Epoch 144:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.02165911883293163 valid 0.01911743561866312
# Training vs. Validation Loss {'Training': 0.02165911883293163, 'Validation': 0.01911743561866312} 145
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 145
# Epoch 145:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.009187475793407344 valid 0.010141064678729586
# Training vs. Validation Loss {'Training': 0.009187475793407344, 'Validation': 0.010141064678729586} 146
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 146
# Epoch 146:
# Accuracy train:0.999018669128418, val:0.9931740760803223
# LOSS train 0.007770692813210189 valid 0.012494085012929665
# Training vs. Validation Loss {'Training': 0.007770692813210189, 'Validation': 0.012494085012929665} 147
# Training vs. Validation accuracy {'Training': 0.999018669128418, 'Validation': 0.9931740760803223} 147
# Epoch 147:
# Accuracy train:1.0, val:0.9965870380401611
# LOSS train 0.010131303251477047 valid 0.013875878399512468
# Training vs. Validation Loss {'Training': 0.010131303251477047, 'Validation': 0.013875878399512468} 148
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9965870380401611} 148
# Epoch 148:
# Accuracy train:1.0, val:0.9965870380401611
# LOSS train 0.006138757112369474 valid 0.01755571722974499
# Training vs. Validation Loss {'Training': 0.006138757112369474, 'Validation': 0.01755571722974499} 149
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 0.9965870380401611} 149
# Epoch 149:
# Accuracy train:0.9970559477806091, val:0.9965870380401611
# LOSS train 0.011348661828032207 valid 0.019948899919458068
# Training vs. Validation Loss {'Training': 0.011348661828032207, 'Validation': 0.019948899919458068} 150
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9965870380401611} 150
# Epoch 150:
# Accuracy train:0.9960745573043823, val:0.9965870380401611
# LOSS train 0.01459930957450221 valid 0.016971437957375695
# Training vs. Validation Loss {'Training': 0.01459930957450221, 'Validation': 0.016971437957375695} 151
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9965870380401611} 151
# stopping at epoch 150, minimum: 0.0022798649827677764
# tensor(0.9966)

# %%
list_label = label_dict_from_config_file("hand_gesture.yaml")
DATA_FOLDER_PATH="./data/"
testset = CustomImageDataset(os.path.join(DATA_FOLDER_PATH,"landmark_test.csv"))

# Test DataLoader instantiation
################## Your Code Here ################## Q6
''' Hoàn thành code bên dưới để  khởi tạo DataLoader cho testset with batch size
20, không cho phép shuffle
'''
test_loader = DataLoader(testset, batch_size=20, shuffle=False)
####################################################

network = NeuralNetwork()
network.load_state_dict(torch.load(best_model_path, weights_only=False))

network.eval()
acc_test = Accuracy(num_classes=len(list_label), task='MULTICLASS')
for i, test_data in enumerate(test_loader):
    test_input, test_label = test_data
    ################## Your Code Here ################## Q7
    '''Hoàn thành code bên dưới để  predict class của cử chỉ và update accuracy
    với kết quả predict và true labels
    '''
    preds = network.predict_with_known_class(test_input)
    acc_test.update(preds, test_label)
    
    ####################################################

print(network.__class__.__name__)
print(f"Accuracy of model:{acc_test.compute().item()}")
print("========================================================================")
# Out:
# NeuralNetwork
# Accuracy of model:0.9724409580230713
# ========================================================================
